# %%
import pandas as pd

path = r"N:\CEFET\TCC\censo-escolar\src\data\ouro\indicadores_municipios.csv"

df = pd.read_csv(path)

resumo = df[['I_imp', 'I_rec', 'I_EAD', 'ICT_2019', 'ICT_2024']].describe()

print(resumo)
# Out:
#             I_imp         I_rec       I_EAD    ICT_2019    ICT_2024
# count  853.000000    853.000000  853.000000  853.000000  853.000000
# mean    -3.005063    -30.370963    0.828103    0.579805    0.751447
# std      5.314423    756.686439    2.676141    0.182202    0.166989
# min    -28.688946 -11133.333333    0.000000    0.083333    0.095238
# 25%     -6.474104    -76.923077    0.000000    0.456140    0.666667
# 50%     -3.259727     50.000000    0.000000    0.583333    0.770115
# 75%     -0.079936    100.000000    0.000000    0.704918    0.876543
# max     24.496233   8300.000000   30.485574    1.000000    1.000000
